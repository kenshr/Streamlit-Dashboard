# %%
import pandas as pd
import numpy as np
import uuid
import datetime
import random
import time

# %% [markdown]
# # Initialize and clean chat dataset

# %%
df = pd.read_csv('../data/healthygamer_gg_testdata.csv')
df
# Out:
#              user           channel  \
# 0     itztony1702  healthygamer_gg
# 1       flaredrip  healthygamer_gg
# 2        modxta23  healthygamer_gg
# 3      reaperdiff  healthygamer_gg
# 4         3rdkira  healthygamer_gg
# ...           ...               ...
# 7725          tmi               NaN
# 7726   0v3rki1192  healthygamer_gg
# 7727       wizz4e  healthygamer_gg
# 7728          tmi               NaN
# 7729          tmi               NaN
#
#                                                 message            timestamp
# 0                                 BibleThump BibleThump  2021-07-16 14:05:22
# 1                       SUPERHERO BibleThump BibleThump  2021-07-16 14:05:23
# 2                                 GOOD DAD FeelsGoodMan  2021-07-16 14:05:23
# 3                                        FeelsStrongMan  2021-07-16 14:05:23
# 4                                             drhgWeird  2021-07-16 14:05:25
# ...                                                 ...                  ...
# 7725                                      tmi.twitch.tv  2021-07-16 15:40:08
# 7726  like does he actually now what content she mak...  2021-07-16 15:41:12
# 7727                   he 100% didn't knew/didn't check  2021-07-16 15:42:48
# 7728                                      tmi.twitch.tv  2021-07-16 15:44:16
# 7729                                      tmi.twitch.tv  2021-07-16 15:48:30
#
# [7730 rows x 4 columns]

# %%
# Remove unnecessary data
# df.drop(['channel'],axis=1,inplace=True)
# Remove nan inputs
df.dropna(axis=0,subset=['user', 'channel'],inplace=True)
# Remove invalid dates
df = df[df.timestamp.str.len() == 19]
df.reset_index(inplace=True,drop=True)

# Anonymize users and channels
df['user'] = 'user_' + pd.Series(pd.factorize(df['user'])[0] + 1).astype(str)
# Randomize channels across 5 options for visualization test
# df['channel'] = 'channel_' + pd.Series(pd.factorize(df['channel'])[0] + 1).astype(str)
df['channel'] = np.random.choice(['channel_1','channel_2','channel_3','channel_4','channel_5'],len(df))

df
# Out:
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#            user    channel                                            message  \
# 0        user_1  channel_4                              BibleThump BibleThump
# 1        user_2  channel_5                    SUPERHERO BibleThump BibleThump
# 2        user_3  channel_3                              GOOD DAD FeelsGoodMan
# 3        user_4  channel_4                                     FeelsStrongMan
# 4        user_5  channel_5                                          drhgWeird
# ...         ...        ...                                                ...
# 7702  user_1393  channel_5                                      no he def new
# 7703  user_1327  channel_1                                                  P
# 7704  user_1393  channel_3        if u have big bobs. then make money with it
# 7705  user_1350  channel_3  like does he actually now what content she mak...
# 7706    user_45  channel_3                   he 100% didn't knew/didn't check
#
#                 timestamp
# 0     2021-07-16 14:05:22
# 1     2021-07-16 14:05:23
# 2     2021-07-16 14:05:23
# 3     2021-07-16 14:05:23
# 4     2021-07-16 14:05:25
# ...                   ...
# 7702  2021-07-16 15:38:51
# 7703  2021-07-16 15:39:05
# 7704  2021-07-16 15:39:29
# 7705  2021-07-16 15:41:12
# 7706  2021-07-16 15:42:48
#
# [7707 rows x 4 columns]

# %%
# Functions to generate random datetime in given range
def str_time_prop(start, end, time_format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formatted in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%Y-%m-%d %H:%M:%S', prop)

# %%
# Randomize times across wider range for visualization test
df['timestamp'] = [random_date("2022-07-01 12:00:00", "2022-12-31 23:59:59", random.random()) for x in range(len(df))]
# Add extra column for just time
df['time'] = df['timestamp'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S").strftime('%H:%M:%S'))
df
# Out:
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#            user    channel                                            message  \
# 0        user_1  channel_4                              BibleThump BibleThump
# 1        user_2  channel_5                    SUPERHERO BibleThump BibleThump
# 2        user_3  channel_3                              GOOD DAD FeelsGoodMan
# 3        user_4  channel_4                                     FeelsStrongMan
# 4        user_5  channel_5                                          drhgWeird
# ...         ...        ...                                                ...
# 7702  user_1393  channel_5                                      no he def new
# 7703  user_1327  channel_1                                                  P
# 7704  user_1393  channel_3        if u have big bobs. then make money with it
# 7705  user_1350  channel_3  like does he actually now what content she mak...
# 7706    user_45  channel_3                   he 100% didn't knew/didn't check
#
#                 timestamp      time
# 0     2022-11-07 08:23:01  08:23:01
# 1     2022-11-24 01:26:44  01:26:44
# 2     2022-08-06 11:31:05  11:31:05
# 3     2022-08-20 09:02:09  09:02:09
# 4     2022-11-03 12:44:44  12:44:44
# ...                   ...       ...
# 7702  2022-08-05 18:41:13  18:41:13
# 7703  2022-08-24 22:01:09  22:01:09
# 7704  2022-09-06 12:38:04  12:38:04
# 7705  2022-11-13 16:54:48  16:54:48
# 7706  2022-07-06 01:43:00  01:43:00
#
# [7707 rows x 5 columns]

# %% [markdown]
# # Create randomized donation dataset to add to chat dataset

# %%
# Add donation column
df['donation'] = 0
df
# Out:
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            user    channel                                            message  \
# 0        user_1  channel_4                              BibleThump BibleThump
# 1        user_2  channel_5                    SUPERHERO BibleThump BibleThump
# 2        user_3  channel_3                              GOOD DAD FeelsGoodMan
# 3        user_4  channel_4                                     FeelsStrongMan
# 4        user_5  channel_5                                          drhgWeird
# ...         ...        ...                                                ...
# 7702  user_1393  channel_5                                      no he def new
# 7703  user_1327  channel_1                                                  P
# 7704  user_1393  channel_3        if u have big bobs. then make money with it
# 7705  user_1350  channel_3  like does he actually now what content she mak...
# 7706    user_45  channel_3                   he 100% didn't knew/didn't check
#
#                 timestamp      time  donation
# 0     2022-11-07 08:23:01  08:23:01         0
# 1     2022-11-24 01:26:44  01:26:44         0
# 2     2022-08-06 11:31:05  11:31:05         0
# 3     2022-08-20 09:02:09  09:02:09         0
# 4     2022-11-03 12:44:44  12:44:44         0
# ...                   ...       ...       ...
# 7702  2022-08-05 18:41:13  18:41:13         0
# 7703  2022-08-24 22:01:09  22:01:09         0
# 7704  2022-09-06 12:38:04  12:38:04         0
# 7705  2022-11-13 16:54:48  16:54:48         0
# 7706  2022-07-06 01:43:00  01:43:00         0
#
# [7707 rows x 6 columns]

# %%
donation_df = pd.DataFrame(columns=["user","channel","message","timestamp","time","donation"])

# Configurable variables
num_donations = 500
donation_pool = [1,5,10,25,100,500,1000]
message_pool = ['Hi','Love your content!','You\'re the best!','']
start_date = "2022-07-01 12:00:00"
end_date = "2022-12-31 23:59:59"
# Static variables
total_users = len(df['user'].unique())
total_channels = len(df['channel'].unique())

for i in range(num_donations):
    random_time = random_date(start_date, end_date, random.random())
    donation_df.loc[len(donation_df.index)] = [
        'user_' + str(random.randint(1,total_users - 1)),
        'channel_' + str(random.randint(1,total_channels - 1)),
        random.choice(message_pool),
        random_time,
        pd.to_datetime(random_time).strftime('%H:%M:%S'),
        random.choice(donation_pool)
    ]
    
donation_df
# Out:
#           user    channel             message            timestamp      time  \
# 0     user_737  channel_4                      2022-11-01 22:21:33  22:21:33
# 1     user_597  channel_2    You're the best!  2022-07-14 20:47:05  20:47:05
# 2     user_268  channel_3                  Hi  2022-07-11 23:32:41  23:32:41
# 3     user_892  channel_4    You're the best!  2022-11-11 22:08:03  22:08:03
# 4    user_1062  channel_1    You're the best!  2022-08-08 15:33:15  15:33:15
# ..         ...        ...                 ...                  ...       ...
# 495  user_1246  channel_1                  Hi  2022-08-14 13:38:40  13:38:40
# 496   user_720  channel_2    You're the best!  2022-07-22 18:17:49  18:17:49
# 497   user_255  channel_3                      2022-12-26 03:44:03  03:44:03
# 498   user_302  channel_4  Love your content!  2022-11-13 14:49:26  14:49:26
# 499   user_702  channel_1                      2022-08-22 21:53:52  21:53:52
#
#     donation
# 0         25
# 1        500
# 2       1000
# 3       1000
# 4          5
# ..       ...
# 495       10
# 496     1000
# 497     1000
# 498       25
# 499       10
#
# [500 rows x 6 columns]

# %%
# Concatenate and sort the DataFrames
combined_df = pd.concat([df,donation_df],ignore_index=True)
combined_df.sort_values(by=['timestamp'],ignore_index=True,inplace=True)
combined_df
# Out:
#            user    channel                              message  \
# 0      user_711  channel_1                   Love your content!
# 1      user_651  channel_3  It feels like you're stuck in limbo
# 2      user_549  channel_1
# 3        user_7  channel_3                       IM CRYING CHAT
# 4     user_1184  channel_4                                   ))
# ...         ...        ...                                  ...
# 8202   user_513  channel_2                              awesome
# 8203   user_514  channel_2                                noooo
# 8204   user_638  channel_2                                 OOOO
# 8205    user_79  channel_1                         what a twist
# 8206  user_1147  channel_4                        link to blog?
#
#                 timestamp      time donation
# 0     2022-07-01 13:44:21  13:44:21       25
# 1     2022-07-01 13:45:09  13:45:09        0
# 2     2022-07-01 15:47:50  15:47:50      500
# 3     2022-07-01 16:08:57  16:08:57        0
# 4     2022-07-01 16:29:48  16:29:48        0
# ...                   ...       ...      ...
# 8202  2022-12-31 19:37:09  19:37:09        0
# 8203  2022-12-31 20:09:42  20:09:42        0
# 8204  2022-12-31 20:16:12  20:16:12        0
# 8205  2022-12-31 22:52:28  22:52:28        0
# 8206  2022-12-31 22:59:58  22:59:58        0
#
# [8207 rows x 6 columns]

# %%
combined_df.to_csv('../data/chat_dataset.csv',index=False)
