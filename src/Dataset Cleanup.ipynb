# %%
import pandas as pd
import numpy as np
import uuid
import datetime
import random
import time

# %% [markdown]
# # Initialize and clean chat dataset

# %%
df = pd.read_csv('../data/healthygamer_gg_testdata.csv')
df
# Out:
#              user           channel  \
# 0     itztony1702  healthygamer_gg
# 1       flaredrip  healthygamer_gg
# 2        modxta23  healthygamer_gg
# 3      reaperdiff  healthygamer_gg
# 4         3rdkira  healthygamer_gg
# ...           ...               ...
# 7725          tmi               NaN
# 7726   0v3rki1192  healthygamer_gg
# 7727       wizz4e  healthygamer_gg
# 7728          tmi               NaN
# 7729          tmi               NaN
#
#                                                 message            timestamp
# 0                                 BibleThump BibleThump  2021-07-16 14:05:22
# 1                       SUPERHERO BibleThump BibleThump  2021-07-16 14:05:23
# 2                                 GOOD DAD FeelsGoodMan  2021-07-16 14:05:23
# 3                                        FeelsStrongMan  2021-07-16 14:05:23
# 4                                             drhgWeird  2021-07-16 14:05:25
# ...                                                 ...                  ...
# 7725                                      tmi.twitch.tv  2021-07-16 15:40:08
# 7726  like does he actually now what content she mak...  2021-07-16 15:41:12
# 7727                   he 100% didn't knew/didn't check  2021-07-16 15:42:48
# 7728                                      tmi.twitch.tv  2021-07-16 15:44:16
# 7729                                      tmi.twitch.tv  2021-07-16 15:48:30
#
# [7730 rows x 4 columns]

# %%
# Remove unnecessary data
# df.drop(['channel'],axis=1,inplace=True)
df.dropna(axis=0,subset=['user', 'channel'],inplace=True)
df.reset_index(inplace=True,drop=True)
# Anonymize users and channels
df['user'] = 'user_' + pd.Series(pd.factorize(df['user'])[0] + 1).astype(str)
df['channel'] = 'channel_' + pd.Series(pd.factorize(df['channel'])[0] + 1).astype(str)
df
# Out:
#            user      channel  \
# 0        user_1    channel_1
# 1        user_2    channel_1
# 2        user_3    channel_1
# 3        user_4    channel_1
# 4        user_5    channel_1
# ...         ...          ...
# 7704  user_1394    channel_1
# 7705  user_1328  channel_148
# 7706  user_1394    channel_1
# 7707  user_1351    channel_1
# 7708    user_45    channel_1
#
#                                                 message            timestamp
# 0                                 BibleThump BibleThump  2021-07-16 14:05:22
# 1                       SUPERHERO BibleThump BibleThump  2021-07-16 14:05:23
# 2                                 GOOD DAD FeelsGoodMan  2021-07-16 14:05:23
# 3                                        FeelsStrongMan  2021-07-16 14:05:23
# 4                                             drhgWeird  2021-07-16 14:05:25
# ...                                                 ...                  ...
# 7704                                      no he def new  2021-07-16 15:38:51
# 7705                                                  P  2021-07-16 15:39:05
# 7706        if u have big bobs. then make money with it  2021-07-16 15:39:29
# 7707  like does he actually now what content she mak...  2021-07-16 15:41:12
# 7708                   he 100% didn't knew/didn't check  2021-07-16 15:42:48
#
# [7709 rows x 4 columns]

# %%
# Remove invalid dates
df = df[df.timestamp.str.len() == 19]
# Add extra column for just time
df['time'] = df['timestamp'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S").strftime('%H:%M:%S'))
df
# Out:
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#            user      channel  \
# 0        user_1    channel_1
# 1        user_2    channel_1
# 2        user_3    channel_1
# 3        user_4    channel_1
# 4        user_5    channel_1
# ...         ...          ...
# 7704  user_1394    channel_1
# 7705  user_1328  channel_148
# 7706  user_1394    channel_1
# 7707  user_1351    channel_1
# 7708    user_45    channel_1
#
#                                                 message            timestamp  \
# 0                                 BibleThump BibleThump  2021-07-16 14:05:22
# 1                       SUPERHERO BibleThump BibleThump  2021-07-16 14:05:23
# 2                                 GOOD DAD FeelsGoodMan  2021-07-16 14:05:23
# 3                                        FeelsStrongMan  2021-07-16 14:05:23
# 4                                             drhgWeird  2021-07-16 14:05:25
# ...                                                 ...                  ...
# 7704                                      no he def new  2021-07-16 15:38:51
# 7705                                                  P  2021-07-16 15:39:05
# 7706        if u have big bobs. then make money with it  2021-07-16 15:39:29
# 7707  like does he actually now what content she mak...  2021-07-16 15:41:12
# 7708                   he 100% didn't knew/didn't check  2021-07-16 15:42:48
#
#           time
# 0     14:05:22
# 1     14:05:23
# 2     14:05:23
# 3     14:05:23
# 4     14:05:25
# ...        ...
# 7704  15:38:51
# 7705  15:39:05
# 7706  15:39:29
# 7707  15:41:12
# 7708  15:42:48
#
# [7707 rows x 5 columns]

# %% [markdown]
# # Create randomized donation dataset to add to chat dataset

# %%
# Functions to generate random datetime in given range
def str_time_prop(start, end, time_format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formatted in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%Y-%m-%d %H:%M:%S', prop)

# %%
# Add donation column
df['donation'] = 0
df
# Out:
# /Users/ken/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            user      channel  \
# 0        user_1    channel_1
# 1        user_2    channel_1
# 2        user_3    channel_1
# 3        user_4    channel_1
# 4        user_5    channel_1
# ...         ...          ...
# 7704  user_1394    channel_1
# 7705  user_1328  channel_148
# 7706  user_1394    channel_1
# 7707  user_1351    channel_1
# 7708    user_45    channel_1
#
#                                                 message            timestamp  \
# 0                                 BibleThump BibleThump  2021-07-16 14:05:22
# 1                       SUPERHERO BibleThump BibleThump  2021-07-16 14:05:23
# 2                                 GOOD DAD FeelsGoodMan  2021-07-16 14:05:23
# 3                                        FeelsStrongMan  2021-07-16 14:05:23
# 4                                             drhgWeird  2021-07-16 14:05:25
# ...                                                 ...                  ...
# 7704                                      no he def new  2021-07-16 15:38:51
# 7705                                                  P  2021-07-16 15:39:05
# 7706        if u have big bobs. then make money with it  2021-07-16 15:39:29
# 7707  like does he actually now what content she mak...  2021-07-16 15:41:12
# 7708                   he 100% didn't knew/didn't check  2021-07-16 15:42:48
#
#           time  donation
# 0     14:05:22         0
# 1     14:05:23         0
# 2     14:05:23         0
# 3     14:05:23         0
# 4     14:05:25         0
# ...        ...       ...
# 7704  15:38:51         0
# 7705  15:39:05         0
# 7706  15:39:29         0
# 7707  15:41:12         0
# 7708  15:42:48         0
#
# [7707 rows x 6 columns]

# %%
donation_df = pd.DataFrame(columns=["user","channel","message","timestamp","time","donation"])

# Configurable variables
num_donations = 500
donation_pool = [1,5,10,25,100,500,1000]
message_pool = ['Hi','Love your content!','You\'re the best!','']
start_date = "2021-07-16 14:05:22"
end_date = "2021-07-16 15:48:30"
# Static variables
total_users = len(df['user'].unique())
total_channels = len(df['channel'].unique())

for i in range(num_donations):
    random_time = random_date(start_date, end_date, random.random())
    donation_df.loc[len(donation_df.index)] = [
        'user_' + str(random.randint(1,total_users - 1)),
        'channel_' + str(random.randint(1,total_channels - 1)),
        random.choice(message_pool),
        random_time,
        pd.to_datetime(random_time).strftime('%H:%M:%S'),
        random.choice(donation_pool)
    ]
    
donation_df
# Out:
#           user      channel             message            timestamp  \
# 0     user_926   channel_16    You're the best!  2021-07-16 15:31:16
# 1     user_898   channel_20  Love your content!  2021-07-16 14:23:05
# 2    user_1019   channel_57                      2021-07-16 14:36:19
# 3    user_1034  channel_115                  Hi  2021-07-16 15:44:05
# 4     user_984   channel_32                      2021-07-16 15:34:57
# ..         ...          ...                 ...                  ...
# 495   user_289    channel_4  Love your content!  2021-07-16 15:18:54
# 496   user_601   channel_48  Love your content!  2021-07-16 14:19:32
# 497   user_800   channel_53                  Hi  2021-07-16 15:45:42
# 498   user_734  channel_139                      2021-07-16 14:52:23
# 499  user_1174  channel_135                      2021-07-16 15:06:31
#
#          time donation
# 0    15:31:16       10
# 1    14:23:05       25
# 2    14:36:19        1
# 3    15:44:05        5
# 4    15:34:57       10
# ..        ...      ...
# 495  15:18:54      500
# 496  14:19:32       25
# 497  15:45:42     1000
# 498  14:52:23        5
# 499  15:06:31       25
#
# [500 rows x 6 columns]

# %%
# Concatenate and sort the DataFrames
combined_df = pd.concat([df,donation_df],ignore_index=True)
combined_df.sort_values(by=['timestamp'],ignore_index=True,inplace=True)
combined_df
# Out:
#            user      channel                          message  \
# 0        user_1    channel_1            BibleThump BibleThump
# 1        user_2    channel_1  SUPERHERO BibleThump BibleThump
# 2        user_3    channel_1            GOOD DAD FeelsGoodMan
# 3        user_4    channel_1                   FeelsStrongMan
# 4        user_5    channel_1                        drhgWeird
# ...         ...          ...                              ...
# 8202   user_775  channel_114
# 8203   user_459  channel_136                               Hi
# 8204  user_1082  channel_133               Love your content!
# 8205  user_1044   channel_89                 You're the best!
# 8206   user_306   channel_53               Love your content!
#
#                 timestamp      time donation
# 0     2021-07-16 14:05:22  14:05:22        0
# 1     2021-07-16 14:05:23  14:05:23        0
# 2     2021-07-16 14:05:23  14:05:23        0
# 3     2021-07-16 14:05:23  14:05:23        0
# 4     2021-07-16 14:05:25  14:05:25        0
# ...                   ...       ...      ...
# 8202  2021-07-16 15:46:35  15:46:35     1000
# 8203  2021-07-16 15:46:46  15:46:46       25
# 8204  2021-07-16 15:47:33  15:47:33       25
# 8205  2021-07-16 15:47:55  15:47:55     1000
# 8206  2021-07-16 15:48:01  15:48:01        1
#
# [8207 rows x 6 columns]

# %%
combined_df.to_csv('../data/chat_dataset.csv')
